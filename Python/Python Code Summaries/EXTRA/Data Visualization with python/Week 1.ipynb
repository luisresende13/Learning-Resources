# %%
###################   DATA PREPARATION   ####################################

# %%
import pandas
import numpy

timeuse=pandas.read_csv('\\Users\luisr\Desktop\Repository\IBM_courses\Samples\\timeuse.csv')
timeuse.replace(':', numpy.nan, inplace=True)
timeuse[timeuse.columns.values[3:]]=timeuse[timeuse.columns.values[3:]].astype('datetime64')

for column in timeuse.columns.values[3:]:
    timeuse[column] = [i.hour+i.minute/60 if str(i)!='NaT' else numpy.nan for i in timeuse[column]]

# %%
aust = pandas.read_excel('\\Users\luisr\Desktop\Repository\IBM_courses\Samples\\australia.xlsx')
aust.drop(['code', 'IRSD'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-7a810f0bc4e0> in <module>
# ----> 1 aust = pandas.read_excel('\\Users\luisr\Data_Frames\\australia.xlsx')
#       2 aust.drop(['code', 'IRSD'], axis=1, inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     302
#     303     if not isinstance(io, ExcelFile):
# --> 304         io = ExcelFile(io, engine=engine)
#     305     elif engine and engine != io.engine:
#     306         raise ValueError(
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in __init__(self, io, engine)
# ...

# %%
cod = pandas.read_csv('\\Users\luisr\Data_Frames\\causesofdeath_france.csv')
tuber = cod[(cod['ICD10']=='Tuberculosis') & (cod['SEX']=='Males')].copy()
tuber['Value'] = tuber['Value'].astype('float')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-f861656d4506> in <module>
# ----> 1 cod = pandas.read_csv('\\Users\luisr\Data_Frames\\causesofdeath_france.csv')
#       2 tuber = cod[(cod['ICD10']=='Tuberculosis') & (cod['SEX']=='Males')].copy()
#       3 tuber['Value'] = tuber['Value'].astype('float')
#
# ...

# %%
##############    -pyplot.hist  ,  pyplot.savefig    ###########################

# %%
import matplotlib.pyplot as plt
import numpy

rand = numpy.random.randn(1000)

#plt.hist(rand, 15)

#plt.title('Distribuição normal com $\mu=0, \sigma=1$')
#plt.savefig('Distribuição normal.png')

# %%
##################    %matplotlib notebook    ######################

# %%
# %matplotlib notebook

import matplotlib.pyplot as plt

#plt.plot(5, 5, 'o')
#plt.title('testing')

# %%
#plt.ylabel('Y')
#plt.xlabel('X')

# %%
##################   dataframe.plot()    ###################

# %%
import pandas


#aust.plot(kind='line', figsize=(8,6))
#plt.xlabel('Index')

#aust['premort'].plot(kind='hist')
#plt.xlabel('pre-mortality')

# %%
############    LAB    ##################################3################

# %%
#######3####   -dataframe.set_index    ############################

# %%
tuber.set_index('TIME', inplace=True)
tuber.drop(['GEO', 'UNIT', 'SEX', 'AGE', 'Flag and Footnotes'], axis=1, inplace=True)

tuber.index.name=None  #remove index name

# %%
##########   -pyplot.style.availabe   ,   -matplotlib.style.use    #################################

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt


#print(plt.style.available)

mpl.style.use(['dark_background'])

timeuse[['Dish washing','Leisure, social and associative life']].plot()
plt.ylabel('Hours')
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">
# Text(0, 0.5, 'Hours')

# %%
########  -plt.text   ################################

# %%
plt.text(2, 1, 'Males in first half')
# Out:
# Text(2, 1, 'Males in first half')

# %%
##########  -dataframe.transpose()   #########################

# %%
#timeuse.transpose()

# %%
##############  dataframe.index.map  #################

# %%
tuber.index = tuber.index.map(str)

type(tuber.index)
# Out:
# pandas.core.indexes.base.Index

# %%
###########   dataframe.sort_values  ,   series.sort_values()   ################33

# %%
# Data frames

#tuber.sort_values(by='Value', ascending=False)
#tuber.transpose().sort_values(by='Value',ascending=False, axis=1)



# Series

#tuber['Value'].sort_values()
